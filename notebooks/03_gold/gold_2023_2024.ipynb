# %% [markdown]
# # State of Data Brasil 2023 — Ouro
# ### Tech Challenge Fase 3 — Grupo 6
# ### Responsável pela edição 2023: Carlos Henrique Freitas
#
# Fonte: [Kaggle — State of Data Brasil](https://www.kaggle.com/datahackers/datasets)

# %% [markdown]
# ## 1. Preparando para Consultas SQL

# %%
# Em produção (AWS), esse caminho vira algo tipo:
# "s3://<bucket-do-grupo>/silver/state_of_data/"
import sys
from pathlib import Path

# Procura a raiz do projeto a partir do diretório atual
CAMINHO_ATUAL = Path.cwd().resolve()

for caminho in [CAMINHO_ATUAL, *CAMINHO_ATUAL.parents]:
    if (caminho / "utils" / "config.py").exists():
        RAIZ_PROJETO = caminho
        break
else:
    raise FileNotFoundError(
        "Não foi possível localizar a raiz do projeto "
        "(utils/config.py)."
    )

# Adiciona a raiz ao PYTHONPATH
if str(RAIZ_PROJETO) not in sys.path:
    sys.path.insert(0, str(RAIZ_PROJETO))

from utils.config import CAMINHO_SILVER, CAMINHO_GOLD_BASE

print("Raiz do projeto:", RAIZ_PROJETO)
print("Silver:", CAMINHO_SILVER)
print("Gold:", CAMINHO_GOLD_BASE)
# Out:
# Raiz do projeto: C:\Users\Henrique\Desktop\Nova pasta
# Silver: C:\Users\Henrique\Desktop\Nova pasta\data\silver\state_of_data_silver
# Gold: C:\Users\Henrique\Desktop\Nova pasta\data\gold

# %%
from pyspark.sql import SparkSession, functions as F
from utils.constants import ponto_medio_salarial, ordem_senioridade, ordem_tempo_experiencia

ANO_PESQUISA = 2023
spark = (
    SparkSession.builder
    .appName(f"state-of-data-{ANO_PESQUISA}-gold")
    .getOrCreate()
)

print(f"Ano de pesquisa: {ANO_PESQUISA}")
print(f"Silver: {CAMINHO_SILVER}")
print(f"Gold: {CAMINHO_GOLD_BASE}")
# Out:
# c:\Users\Henrique\AppData\Local\Programs\Python\Python314\Lib\site-packages\pyspark\testing\utils.py:127: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()
# Ano de pesquisa: 2023
# Silver: C:\Users\Henrique\Desktop\Nova pasta\data\silver\state_of_data_silver
# Gold: C:\Users\Henrique\Desktop\Nova pasta\data\gold

# %%
# Em produção (AWS), esse caminho vira algo tipo:
# "s3://<bucket-do-grupo>/silver/state_of_data/"
df_silver = (
    spark.read
    .parquet(str(CAMINHO_SILVER))
    .filter(F.col("ano_pesquisa") == ANO_PESQUISA)
)

print(f"{df_silver.count()} linhas, {len(df_silver.columns)} colunas")
# Out:
# 5293 linhas, 170 colunas

# %%
df_silver.createOrReplaceTempView("state_of_data_2023")

# %% [markdown]
# ## 2. Regras de negócio — resumo de referência
#
# Antes de realizar as consultas e plotar os gráficos, quero deixar tudo que descobri sobre escopo e
# agregação registrado num lugar só, fácil de consultar - sem precisar reler
# toda a investigação toda vez que alguém (inclusive eu, num notebook futuro)
# precisar lembrar qual filtro usar em qual coluna.
#
# **Filtros de escopo**
#
# | Regra | Descrição | Aplica em |
# | :--- | :--- | :--- |
# | `aplica_analise_emprego = true` | Exclui desempregados, apenas estudantes ou área acadêmica. | `setor_empresa`, `faixa_salarial`, `tempo_experiencia_dados`, `tempo_experiencia_ti`, `modelo_trabalho_atual`, `modelo_trabalho_ideal`, `satisfeito_empresa` |
# | `aplica_analise_tecnica = true` | Exclui quem não tem `cargo_atual` preenchido. | `cargo_atual`, `nivel_senioridade` e os blocos técnicos (`linguagens_trabalho`, `banco_dados`, `fontes_dados`, `cloud`, `ferramenta_bi`, `ia_tipo_uso`) |
# | `aplica_analise_gestor = true` | Só quem respondeu `atua_como_gestor = Sim`. | `cargos_no_time_dados`, `desafios_gestor`, `ia_motivos_nao_uso` |
# | `aplica_analise_busca_oportunidade = true` | O inverso exato de `aplica_analise_emprego` - só quem está fora do mercado de trabalho ativo. | `objetivo_carreira` |
# | `satisfeito_empresa = false` | Caso especial: gatilho não é escopo geral, é a resposta de outra pergunta. | `motivo_insatisfacao` |
# | *(sem filtro)* | Pergunta de perfil (bloco P1), respondida por todo mundo, independente de situação de trabalho. | `experiencia_prejudicada` |
#
# **Nota sobre `ia_tipo_uso`:** na teoria, o gatilho certo dessa pergunta é "não
# ser gestor" (`aplica_analise_gestor = false`). Na prática, usei
# `aplica_analise_tecnica` mesmo assim, porque descobri que nessa base as duas
# condições descrevem exatamente o mesmo grupo de gente: quem é gestor responde
# uma pergunta de cargo diferente (`"Cargo como Gestor"`, não capturada nessa
# Silver), então `cargo_atual` preenchido e "não ser gestor" acabam sendo
# sinônimos aqui. Funciona, mas é bom deixar registrado o porquê, pra não
# parecer coincidência da próxima vez que alguém for mexer nisso.
#
# **Regra de agregação (múltipla escolha)**
#
# Colunas dos blocos viraram boolean (`true`/`false`), não nulo/preenchido. Pra
# contar quantas pessoas marcaram uma opção, uso soma condicional, nunca
# `COUNT`:
#
# ```sql
# -- Correto: conta só quem marcou true
# SUM(CASE WHEN coluna THEN 1 ELSE 0 END) AS total
#
# -- Errado: COUNT considera qualquer valor não-nulo, incluindo os `false`
# COUNT(coluna)
# ```
#
# **Cuidado com viés de composição:** ao comparar médias entre grupos (gênero,
# região, etc.), sempre olhar também aberto por cargo/senioridade antes de
# confiar na média simples - um grupo com mais gente Sênior sai com média mais
# alta só por causa disso, não por um efeito real do grupo.

# %% [markdown]
# ## 3. Respondendo as perguntas do Tech Challenge

# %%
# view auxiliar com a faixa salarial convertida pra número (ponto médio da
# faixa) - útil pra calcular médias e comparar grupos
case_faixa_salarial = " ".join(
    f"WHEN '{faixa}' THEN {valor}" for faixa, valor in ponto_medio_salarial.items()
)

spark.sql(f"""
    CREATE OR REPLACE TEMP VIEW state_of_data_2023_num AS
    SELECT *,
        CASE faixa_salarial
            {case_faixa_salarial}
            ELSE NULL
        END AS faixa_salarial_num
    FROM state_of_data_2023
""")
print("Views criadas: state_of_data_2023 e state_of_data_2023_num")
# Out:
# Views criadas: state_of_data_2023 e state_of_data_2023_num

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import warnings
warnings.filterwarnings('ignore')

# Desativa a busca pelo PyArrow no Spark
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", "false")

def grafico_barh(pdf, col_categoria, col_valor, titulo, xlabel, cor='#2E86AB', figsize=(9, 5)):
    """Gráfico de barra horizontal a partir de um pandas DataFrame (resultado de toPandas())."""
    pdf = pdf.sort_values(col_valor)
    plt.figure(figsize=figsize)
    plt.barh(pdf[col_categoria].astype(str), pdf[col_valor], color=cor)
    plt.title(titulo)
    plt.xlabel(xlabel)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### P1 — Como está estruturado o mercado brasileiro de Dados?

# %% [markdown]
# **1. Como se distribui a situação de trabalho dos profissionais?**

# %%
resultado_p1_1 = spark.sql("""
    SELECT
        situacao_trabalho,
        COUNT(*) AS total,
        ROUND(100.0 * COUNT(*) / SUM(COUNT(*)) OVER (), 1) AS percentual
    FROM state_of_data_2023
    GROUP BY situacao_trabalho
    ORDER BY total DESC
""")

resultado_p1_1.show(truncate=False)

pdf_p1_1 = resultado_p1_1.toPandas()
grafico_barh(pdf_p1_1 , 'situacao_trabalho', 'total',
             'Situação de trabalho dos respondentes 2023', 'Quantidade de pessoas')
# Out:
# +---------------------------------------------------------------+-----+----------+
# |situacao_trabalho                                              |total|percentual|
# +---------------------------------------------------------------+-----+----------+
# |Empregado (CLT)                                                |3604 |68.1      |
# |Empreendedor ou Empregado (CNPJ)                               |555  |10.5      |
# |Desempregado, buscando recolocação                             |361  |6.8       |
# |Estagiário                                                     |207  |3.9       |
# |Servidor Público                                               |146  |2.8       |
# |Vivo no Brasil e trabalho remoto para empresa de fora do Brasil|116  |2.2       |
# |Somente Estudante (graduação)                                  |78   |1.5       |
# |Vivo fora do Brasil e trabalho para empresa de fora do Brasil  |64   |1.2       |
# |Trabalho na área Acadêmica/Pesquisador                         |63   |1.2       |
# |Freelancer                                                     |51   |1.0       |
# |Somente Estudante (pós-graduação)                              |28   |0.5       |
# |Prefiro não informar                                           |10   |0.2       |
# |Desempregado e não estou buscando recolocação                  |10   |0.2       |
# +---------------------------------------------------------------+-----+----------+

# %% [markdown]
# **2. Em quais setores da economia esses profissionais mais atuam? (top 10)**

# %%
resultado_p1_2 = spark.sql("""
    SELECT setor_empresa, COUNT(*) AS total
    FROM state_of_data_2023
    WHERE aplica_analise_emprego = true
    GROUP BY setor_empresa
    ORDER BY total DESC
    LIMIT 10
""")
resultado_p1_2.show(truncate=False)

pdf_p1_2 = resultado_p1_2.toPandas()
grafico_barh(pdf_p1_2 , 'setor_empresa', 'total',
                'Top 10 setores de atuação das empresas dos respondentes 2023', 'Quantidade de pessoas')
# Out:
# +------------------------------+-----+
# |setor_empresa                 |total|
# +------------------------------+-----+
# |Finanças ou Bancos            |927  |
# |Tecnologia/Fábrica de Software|857  |
# |Varejo                        |392  |
# |Área de Consultoria           |389  |
# |Outra Opção                   |344  |
# |Indústria                     |313  |
# |Educação                      |209  |
# |Área da Saúde                 |201  |
# |Setor Público                 |174  |
# |Internet/Ecommerce            |129  |
# +------------------------------+-----+

# %% [markdown]
# **3. Qual a distribuição de cargos atuais na área de dados?**

# %%
resultado_p1_3 = spark.sql("""
    SELECT cargo_atual, COUNT(*) AS total
    FROM state_of_data_2023
    WHERE aplica_analise_tecnica = true
    GROUP BY cargo_atual
    ORDER BY total DESC
""")
resultado_p1_3.show(truncate=False)

pdf_p1_3 = resultado_p1_3.toPandas()
grafico_barh(pdf_p1_3 , 'cargo_atual', 'total', 'Distribuição de Cargos 2023', 'Total')
# Out:
# +-------------------------------------------------------------------+-----+
# |cargo_atual                                                        |total|
# +-------------------------------------------------------------------+-----+
# |Analista de Dados/Data Analyst                                     |907  |
# |Cientista de Dados/Data Scientist                                  |687  |
# |Engenheiro de Dados/Arquiteto de Dados/Data Engineer/Data Architect|684  |
# |Analista de BI/BI Analyst                                          |506  |
# |Outra Opção                                                        |262  |
# |Analista de Negócios/Business Analyst                              |195  |
# |Analytics Engineer                                                 |139  |
# |Desenvolvedor/ Engenheiro de Software/ Analista de Sistemas        |105  |
# |Data Product Manager/ Product Manager (PM/APM/DPM/GPM/PO)          |81   |
# |Engenheiro de Machine Learning/ML Engineer/AI Engineer             |75   |
# |Analista de Suporte/Analista Técnico                               |72   |
# |Analista de Inteligência de Mercado/Market Intelligence            |39   |
# |Outras Engenharias (não inclui dev)                                |31   |
# |Professor/Pesquisador                                              |28   |
# |Estatístico                                                        |21   |
# |DBA/Administrador de Banco de Dados                                |20   |
# |Economista                                                         |5    |
# +-------------------------------------------------------------------+-----+

# %% [markdown]
# **4. Qual a distribuição de senioridade no mercado?**

# %%
resultado_p1_4 = spark.sql("""
    SELECT
        nivel_senioridade,
        COUNT(*) AS total,
        ROUND(100.0 * COUNT(*) / SUM(COUNT(*)) OVER (), 0) AS percentual
    FROM state_of_data_2023
    WHERE aplica_analise_tecnica = true
    GROUP BY nivel_senioridade
    ORDER BY total DESC
""")
resultado_p1_4.show(truncate=False)

pdf_p1_4 = resultado_p1_4.toPandas()
grafico_barh(pdf_p1_4 , 'nivel_senioridade', 'total', 'Distribuição de Nível de Senioridade 2023', 'Total')
# Out:
# +-----------------+-----+----------+
# |nivel_senioridade|total|percentual|
# +-----------------+-----+----------+
# |Sênior           |1419 |37        |
# |Pleno            |1392 |36        |
# |Júnior           |1046 |27        |
# +-----------------+-----+----------+

# %% [markdown]
# **5. Qual % dos profissionais atua como gestor?**

# %%
resultado_p1_5 = spark.sql("""
    SELECT
        ROUND(100.0 * SUM(CASE WHEN aplica_analise_gestor THEN 1 ELSE 0 END) / COUNT(*), 0) AS pct_gestores
    FROM state_of_data_2023
    WHERE aplica_analise_emprego = true
""")
resultado_p1_5.show(truncate=False)

# Extrai o valor retornado pela query PySpark
pct_val = resultado_p1_5.collect()[0]['pct_gestores']
valor_formatado = f"{int(pct_val)}%"

# Cria a figura do Card
fig, ax = plt.subplots(figsize=(4, 2.2))
ax.axis('off')

# Desenha o fundo do card
card = patches.FancyBboxPatch(
    (0.05, 0.05), 0.9, 0.9,
    boxstyle="round,pad=0.03",
    facecolor="#F8F9FA",
    edgecolor="#D0D7DE",
    linewidth=1.5
)
ax.add_patch(card)

# Adiciona o valor retornado da query
ax.text(0.5, 0.58, valor_formatado, fontsize=38, fontweight='bold', ha='center', va='center', color='#0969DA')

# Adiciona a legenda
ax.text(0.5, 0.28, '% Dos profissionais que atuam como Gestores 2023', fontsize=9, ha='center', va='center', color='#57606A')

plt.tight_layout()
plt.show()
# Out:
# +------------+
# |pct_gestores|
# +------------+
# |19          |
# +------------+

# %% [markdown]
# **6. Qual é a relação entre tempo de experiência em dados e nível de senioridade?**

# %%
resultado_p1_6 = spark.sql("""
    SELECT tempo_experiencia_dados, nivel_senioridade, COUNT(*) AS total
    FROM state_of_data_2023
    WHERE aplica_analise_emprego = true AND aplica_analise_tecnica = true
    GROUP BY tempo_experiencia_dados, nivel_senioridade
    ORDER BY tempo_experiencia_dados, total DESC
""")
resultado_p1_6.show(50, truncate=False)
# Out:
# +--------------------------------------+-----------------+-----+
# |tempo_experiencia_dados               |nivel_senioridade|total|
# +--------------------------------------+-----------------+-----+
# |Mais de 10 anos                       |Sênior           |248  |
# |Mais de 10 anos                       |Pleno            |32   |
# |Mais de 10 anos                       |Júnior           |8    |
# |Menos de 1 ano                        |Júnior           |344  |
# |Menos de 1 ano                        |Pleno            |64   |
# |Menos de 1 ano                        |Sênior           |21   |
# |Não tenho experiência na área de dados|Júnior           |67   |
# |Não tenho experiência na área de dados|Pleno            |35   |
# |Não tenho experiência na área de dados|Sênior           |29   |
# |de 1 a 2 anos                         |Júnior           |523  |
# |de 1 a 2 anos                         |Pleno            |489  |
# |de 1 a 2 anos                         |Sênior           |103  |
# |de 3 a 4 anos                         |Pleno            |546  |
# |de 3 a 4 anos                         |Sênior           |342  |
# |de 3 a 4 anos                         |Júnior           |88   |
# |de 5 a 6 anos                         |Sênior           |441  |
# |de 5 a 6 anos                         |Pleno            |186  |
# |de 5 a 6 anos                         |Júnior           |13   |
# |de 7 a 10 anos                        |Sênior           |235  |
# |de 7 a 10 anos                        |Pleno            |40   |
# |de 7 a 10 anos                        |Júnior           |3    |
# +--------------------------------------+-----------------+-----+

# %% [markdown]
# **7. Qual modelo de trabalho predomina (remoto, híbrido, presencial) e qual é o desejado?**

# %%
import textwrap

resultado_p1_7 = spark.sql("""
    SELECT modelo_trabalho_atual, COUNT(*) AS total
    FROM state_of_data_2023
    WHERE aplica_analise_emprego = true
    GROUP BY modelo_trabalho_atual
    ORDER BY total DESC
""")

resultado_p1_7.show(truncate=False)

pdf_p1_7 = resultado_p1_7.toPandas()

# Aplica a quebra de linha para textos longos (ex: máx. 30 caracteres por linha)
pdf_p1_7['modelo_trabalho_formatado'] = pdf_p1_7['modelo_trabalho_atual'].apply(
    lambda x: textwrap.fill(str(x), width=30)
)

grafico_barh(pdf_p1_7, 'modelo_trabalho_formatado', 'total',
             'Modelo de trabalho 2023', 'Quantidade de pessoas')
# Out:
# +--------------------------------------------------------------------------------------------------------------+-----+
# |modelo_trabalho_atual                                                                                         |total|
# +--------------------------------------------------------------------------------------------------------------+-----+
# |Modelo 100% remoto                                                                                            |2201 |
# |Modelo híbrido flexível (o funcionário tem liberdade para escolher quando estar no escritório presencialmente)|972  |
# |Modelo híbrido com dias fixos de trabalho presencial                                                          |790  |
# |Modelo 100% presencial                                                                                        |790  |
# +--------------------------------------------------------------------------------------------------------------+-----+

# %%
import textwrap


resultado_p1_7_1 = spark.sql("""
    SELECT modelo_trabalho_ideal, COUNT(*) AS total
    FROM state_of_data_2023
    WHERE aplica_analise_emprego = true
    GROUP BY modelo_trabalho_ideal
    ORDER BY total DESC
""")

resultado_p1_7_1.show(truncate=False)

pdf_p1_7_1 = resultado_p1_7_1.toPandas()

# Aplica a quebra de linha para textos longos
pdf_p1_7_1['modelo_trabalho_ideal_formatado'] = pdf_p1_7_1['modelo_trabalho_ideal'].apply(
    lambda x: textwrap.fill(str(x), width=30)
)

grafico_barh(pdf_p1_7_1, 'modelo_trabalho_ideal_formatado', 'total',
             'Modelo de trabalho desejado 2023', 'Quantidade de pessoas')
# Out:
# +--------------------------------------------------------------------------------------------------------------+-----+
# |modelo_trabalho_ideal                                                                                         |total|
# +--------------------------------------------------------------------------------------------------------------+-----+
# |Modelo híbrido flexível (o funcionário tem liberdade para escolher quando estar no escritório presencialmente)|2144 |
# |Modelo 100% remoto                                                                                            |2124 |
# |Modelo híbrido com dias fixos de trabalho presencial                                                          |389  |
# |Modelo 100% presencial                                                                                        |96   |
# +--------------------------------------------------------------------------------------------------------------+-----+

# %% [markdown]
# **8. Como se distribui o porte das empresas que possuem times de dados?**

# %%
resultado_p1_8 = spark.sql("""
    SELECT num_funcionarios, COUNT(*) AS total
    FROM state_of_data_2023
    WHERE aplica_analise_emprego = true
      AND num_funcionarios IS NOT NULL
    GROUP BY num_funcionarios
    ORDER BY total DESC
""")

resultado_p1_8.show(20, truncate=False)

pdf_p1_1_8 = resultado_p1_8.toPandas()
grafico_barh(pdf_p1_1_8, 'num_funcionarios', 'total',
             'Número de funcionários da empresa 2023', 'Quantidade de pessoas')
# Out:
# +----------------+-----+
# |num_funcionarios|total|
# +----------------+-----+
# |Acima de 3.000  |2077 |
# |de 101 a 500    |823  |
# |de 1.001 a 3.000|520  |
# |de 501 a 1.000  |445  |
# |de 11 a 50      |348  |
# |de 51 a 100     |326  |
# |de 1 a 5        |124  |
# |de 6 a 10       |89   |
# +----------------+-----+

# %% [markdown]
# ## P2 — Quais perfis profissionais são mais valorizados pelo mercado?

# %% [markdown]
# **1. Qual a faixa salarial por cargo e nivel de senioridade?**

# %%
resultado_p2_1 = spark.sql("""
    SELECT cargo_atual, nivel_senioridade, faixa_salarial, COUNT(*) AS total
    FROM state_of_data_2023
    WHERE aplica_analise_emprego = true AND aplica_analise_tecnica = true
    GROUP BY cargo_atual, nivel_senioridade, faixa_salarial
    ORDER BY cargo_atual, nivel_senioridade, total DESC
""")
resultado_p2_1.show(100, truncate=False)
# Out:
# +-------------------------------------------------------+-----------------+--------------------------------+-----+
# |cargo_atual                                            |nivel_senioridade|faixa_salarial                  |total|
# +-------------------------------------------------------+-----------------+--------------------------------+-----+
# |Analista de BI/BI Analyst                              |Júnior           |de R$ 1.001/mês a R$ 2.000/mês  |45   |
# |Analista de BI/BI Analyst                              |Júnior           |de R$ 4.001/mês a R$ 6.000/mês  |42   |
# |Analista de BI/BI Analyst                              |Júnior           |de R$ 2.001/mês a R$ 3.000/mês  |39   |
# |Analista de BI/BI Analyst                              |Júnior           |de R$ 3.001/mês a R$ 4.000/mês  |37   |
# |Analista de BI/BI Analyst                              |Júnior           |de R$ 6.001/mês a R$ 8.000/mês  |9    |
# |Analista de BI/BI Analyst                              |Júnior           |Menos de R$ 1.000/mês           |4    |
# |Analista de BI/BI Analyst                              |Pleno            |de R$ 4.001/mês a R$ 6.000/mês  |85   |
# |Analista de BI/BI Analyst                              |Pleno            |de R$ 6.001/mês a R$ 8.000/mês  |49   |
# |Analista de BI/BI Analyst                              |Pleno            |de R$ 8.001/mês a R$ 12.000/mês |29   |
# |Analista de BI/BI Analyst                              |Pleno            |de R$ 3.001/mês a R$ 4.000/mês  |21   |
# |Analista de BI/BI Analyst                              |Pleno            |de R$ 2.001/mês a R$ 3.000/mês  |8    |
# |Analista de BI/BI Analyst                              |Pleno            |de R$ 1.001/mês a R$ 2.000/mês  |2    |
# |Analista de BI/BI Analyst                              |Pleno            |de R$ 12.001/mês a R$ 16.000/mês|2    |
# |Analista de BI/BI Analyst                              |Pleno            |de R$ 16.001/mês a R$ 20.000/mês|2    |
# |Analista de BI/BI Analyst                              |Pleno            |Acima de R$ 40.001/mês          |1    |
# |Analista de BI/BI Analyst                              |Pleno            |de R$ 20.001/mês a R$ 25.000/mês|1    |
# |Analista de BI/BI Analyst                              |Sênior           |de R$ 8.001/mês a R$ 12.000/mês |55   |
# |Analista de BI/BI Analyst                              |Sênior           |de R$ 6.001/mês a R$ 8.000/mês  |33   |
# |Analista de BI/BI Analyst                              |Sênior           |de R$ 12.001/mês a R$ 16.000/mês|18   |
# |Analista de BI/BI Analyst                              |Sênior           |de R$ 4.001/mês a R$ 6.000/mês  |12   |
# |Analista de BI/BI Analyst                              |Sênior           |de R$ 20.001/mês a R$ 25.000/mês|3    |
# |Analista de BI/BI Analyst                              |Sênior           |de R$ 25.001/mês a R$ 30.000/mês|3    |
# |Analista de BI/BI Analyst                              |Sênior           |de R$ 3.001/mês a R$ 4.000/mês  |3    |
# |Analista de BI/BI Analyst                              |Sênior           |de R$ 16.001/mês a R$ 20.000/mês|1    |
# |Analista de BI/BI Analyst                              |Sênior           |de R$ 30.001/mês a R$ 40.000/mês|1    |
# |Analista de BI/BI Analyst                              |Sênior           |de R$ 2.001/mês a R$ 3.000/mês  |1    |
# |Analista de Dados/Data Analyst                         |Júnior           |de R$ 4.001/mês a R$ 6.000/mês  |94   |
# |Analista de Dados/Data Analyst                         |Júnior           |de R$ 3.001/mês a R$ 4.000/mês  |62   |
# |Analista de Dados/Data Analyst                         |Júnior           |de R$ 2.001/mês a R$ 3.000/mês  |54   |
# |Analista de Dados/Data Analyst                         |Júnior           |de R$ 1.001/mês a R$ 2.000/mês  |47   |
# |Analista de Dados/Data Analyst                         |Júnior           |de R$ 6.001/mês a R$ 8.000/mês  |13   |
# |Analista de Dados/Data Analyst                         |Júnior           |Menos de R$ 1.000/mês           |2    |
# |Analista de Dados/Data Analyst                         |Júnior           |de R$ 8.001/mês a R$ 12.000/mês |2    |
# |Analista de Dados/Data Analyst                         |Júnior           |de R$ 12.001/mês a R$ 16.000/mês|2    |
# |Analista de Dados/Data Analyst                         |Júnior           |de R$ 16.001/mês a R$ 20.000/mês|1    |
# |Analista de Dados/Data Analyst                         |Pleno            |de R$ 6.001/mês a R$ 8.000/mês  |111  |
# |Analista de Dados/Data Analyst                         |Pleno            |de R$ 4.001/mês a R$ 6.000/mês  |110  |
# |Analista de Dados/Data Analyst                         |Pleno            |de R$ 8.001/mês a R$ 12.000/mês |57   |
# |Analista de Dados/Data Analyst                         |Pleno            |de R$ 3.001/mês a R$ 4.000/mês  |46   |
# |Analista de Dados/Data Analyst                         |Pleno            |de R$ 2.001/mês a R$ 3.000/mês  |13   |
# |Analista de Dados/Data Analyst                         |Pleno            |de R$ 12.001/mês a R$ 16.000/mês|12   |
# |Analista de Dados/Data Analyst                         |Pleno            |de R$ 1.001/mês a R$ 2.000/mês  |4    |
# |Analista de Dados/Data Analyst                         |Pleno            |de R$ 16.001/mês a R$ 20.000/mês|4    |
# |Analista de Dados/Data Analyst                         |Pleno            |Acima de R$ 40.001/mês          |1    |
# |Analista de Dados/Data Analyst                         |Pleno            |de R$ 30.001/mês a R$ 40.000/mês|1    |
# |Analista de Dados/Data Analyst                         |Pleno            |de R$ 20.001/mês a R$ 25.000/mês|1    |
# |Analista de Dados/Data Analyst                         |Sênior           |de R$ 8.001/mês a R$ 12.000/mês |141  |
# |Analista de Dados/Data Analyst                         |Sênior           |de R$ 12.001/mês a R$ 16.000/mês|51   |
# |Analista de Dados/Data Analyst                         |Sênior           |de R$ 6.001/mês a R$ 8.000/mês  |38   |
# |Analista de Dados/Data Analyst                         |Sênior           |de R$ 4.001/mês a R$ 6.000/mês  |17   |
# |Analista de Dados/Data Analyst                         |Sênior           |de R$ 16.001/mês a R$ 20.000/mês|11   |
# |Analista de Dados/Data Analyst                         |Sênior           |de R$ 20.001/mês a R$ 25.000/mês|5    |
# |Analista de Dados/Data Analyst                         |Sênior           |de R$ 30.001/mês a R$ 40.000/mês|3    |
# |Analista de Dados/Data Analyst                         |Sênior           |de R$ 25.001/mês a R$ 30.000/mês|2    |
# |Analista de Dados/Data Analyst                         |Sênior           |de R$ 3.001/mês a R$ 4.000/mês  |1    |
# |Analista de Dados/Data Analyst                         |Sênior           |Acima de R$ 40.001/mês          |1    |
# |Analista de Inteligência de Mercado/Market Intelligence|Júnior           |de R$ 2.001/mês a R$ 3.000/mês  |7    |
# |Analista de Inteligência de Mercado/Market Intelligence|Júnior           |de R$ 1.001/mês a R$ 2.000/mês  |5    |
# |Analista de Inteligência de Mercado/Market Intelligence|Júnior           |de R$ 4.001/mês a R$ 6.000/mês  |2    |
# |Analista de Inteligência de Mercado/Market Intelligence|Júnior           |de R$ 8.001/mês a R$ 12.000/mês |1    |
# |Analista de Inteligência de Mercado/Market Intelligence|Júnior           |de R$ 3.001/mês a R$ 4.000/mês  |1    |
# |Analista de Inteligência de Mercado/Market Intelligence|Pleno            |de R$ 4.001/mês a R$ 6.000/mês  |6    |
# |Analista de Inteligência de Mercado/Market Intelligence|Pleno            |de R$ 6.001/mês a R$ 8.000/mês  |5    |
# |Analista de Inteligência de Mercado/Market Intelligence|Pleno            |de R$ 3.001/mês a R$ 4.000/mês  |3    |
# |Analista de Inteligência de Mercado/Market Intelligence|Pleno            |de R$ 8.001/mês a R$ 12.000/mês |1    |
# |Analista de Inteligência de Mercado/Market Intelligence|Sênior           |de R$ 8.001/mês a R$ 12.000/mês |5    |
# |Analista de Inteligência de Mercado/Market Intelligence|Sênior           |de R$ 20.001/mês a R$ 25.000/mês|1    |
# |Analista de Inteligência de Mercado/Market Intelligence|Sênior           |de R$ 4.001/mês a R$ 6.000/mês  |1    |
# |Analista de Inteligência de Mercado/Market Intelligence|Sênior           |de R$ 6.001/mês a R$ 8.000/mês  |1    |
# |Analista de Negócios/Business Analyst                  |Júnior           |de R$ 4.001/mês a R$ 6.000/mês  |16   |
# |Analista de Negócios/Business Analyst                  |Júnior           |de R$ 2.001/mês a R$ 3.000/mês  |12   |
# |Analista de Negócios/Business Analyst                  |Júnior           |de R$ 3.001/mês a R$ 4.000/mês  |8    |
# |Analista de Negócios/Business Analyst                  |Júnior           |de R$ 1.001/mês a R$ 2.000/mês  |5    |
# |Analista de Negócios/Business Analyst                  |Júnior           |de R$ 6.001/mês a R$ 8.000/mês  |2    |
# |Analista de Negócios/Business Analyst                  |Pleno            |de R$ 4.001/mês a R$ 6.000/mês  |23   |
# |Analista de Negócios/Business Analyst                  |Pleno            |de R$ 6.001/mês a R$ 8.000/mês  |21   |
# |Analista de Negócios/Business Analyst                  |Pleno            |de R$ 8.001/mês a R$ 12.000/mês |9    |
# |Analista de Negócios/Business Analyst                  |Pleno            |de R$ 3.001/mês a R$ 4.000/mês  |8    |
# |Analista de Negócios/Business Analyst                  |Pleno            |de R$ 2.001/mês a R$ 3.000/mês  |5    |
# |Analista de Negócios/Business Analyst                  |Pleno            |de R$ 12.001/mês a R$ 16.000/mês|2    |
# |Analista de Negócios/Business Analyst                  |Pleno            |de R$ 16.001/mês a R$ 20.000/mês|1    |
# |Analista de Negócios/Business Analyst                  |Sênior           |de R$ 8.001/mês a R$ 12.000/mês |36   |
# |Analista de Negócios/Business Analyst                  |Sênior           |de R$ 6.001/mês a R$ 8.000/mês  |23   |
# |Analista de Negócios/Business Analyst                  |Sênior           |de R$ 12.001/mês a R$ 16.000/mês|10   |
# |Analista de Negócios/Business Analyst                  |Sênior           |de R$ 4.001/mês a R$ 6.000/mês  |8    |
# |Analista de Negócios/Business Analyst                  |Sênior           |de R$ 16.001/mês a R$ 20.000/mês|4    |
# |Analista de Negócios/Business Analyst                  |Sênior           |de R$ 3.001/mês a R$ 4.000/mês  |1    |
# |Analista de Negócios/Business Analyst                  |Sênior           |de R$ 20.001/mês a R$ 25.000/mês|1    |
# |Analista de Suporte/Analista Técnico                   |Júnior           |de R$ 2.001/mês a R$ 3.000/mês  |12   |
# |Analista de Suporte/Analista Técnico                   |Júnior           |de R$ 1.001/mês a R$ 2.000/mês  |6    |
# |Analista de Suporte/Analista Técnico                   |Júnior           |de R$ 3.001/mês a R$ 4.000/mês  |6    |
# |Analista de Suporte/Analista Técnico                   |Júnior           |de R$ 4.001/mês a R$ 6.000/mês  |2    |
# |Analista de Suporte/Analista Técnico                   |Pleno            |de R$ 3.001/mês a R$ 4.000/mês  |9    |
# |Analista de Suporte/Analista Técnico                   |Pleno            |de R$ 4.001/mês a R$ 6.000/mês  |9    |
# |Analista de Suporte/Analista Técnico                   |Pleno            |de R$ 2.001/mês a R$ 3.000/mês  |5    |
# |Analista de Suporte/Analista Técnico                   |Pleno            |de R$ 6.001/mês a R$ 8.000/mês  |3    |
# |Analista de Suporte/Analista Técnico                   |Pleno            |de R$ 8.001/mês a R$ 12.000/mês |2    |
# |Analista de Suporte/Analista Técnico                   |Pleno            |de R$ 1.001/mês a R$ 2.000/mês  |2    |
# |Analista de Suporte/Analista Técnico                   |Pleno            |Menos de R$ 1.000/mês           |1    |
# |Analista de Suporte/Analista Técnico                   |Sênior           |de R$ 8.001/mês a R$ 12.000/mês |5    |
# +-------------------------------------------------------+-----------------+--------------------------------+-----+
# only showing top 100 rows

# %% [markdown]
# **2. Profissionais com mais tempo de experiência em TI e Dados são mais bem remunerados?**

# %%
import textwrap

# 1. Análise por Tempo de Experiência em Dados
case_ordem_exp = " ".join(
    f"WHEN '{valor}' THEN {i}" for i, valor in enumerate(ordem_tempo_experiencia)
)

resultado_p2_2 = spark.sql(f"""
    SELECT 
        tempo_experiencia_dados, 
        ROUND(AVG(faixa_salarial_num), 0) AS salario_medio_estimado
    FROM state_of_data_2023_num
    WHERE aplica_analise_emprego = true
    GROUP BY tempo_experiencia_dados
    ORDER BY CASE tempo_experiencia_dados {case_ordem_exp} ELSE 99 END ASC
""")
resultado_p2_2.show(truncate=False)

pdf_p2_2 = resultado_p2_2.toPandas()

# Aplica a quebra de linha nos textos da experiência em Dados
pdf_p2_2['tempo_experiencia_dados_formatado'] = pdf_p2_2['tempo_experiencia_dados'].apply(
    lambda x: textwrap.fill(str(x), width=30)
)

grafico_barh(pdf_p2_2, 'tempo_experiencia_dados_formatado', 'salario_medio_estimado',
             'Salário médio estimado por tempo de experiência em dados', 'Salário médio estimado (R$)')


# 2. Análise por Tempo de Experiência em TI
resultado_p2_2_1 = spark.sql(f"""
    SELECT 
        tempo_experiencia_ti, 
        ROUND(AVG(faixa_salarial_num), 0) AS salario_medio_estimado
    FROM state_of_data_2023_num
    WHERE aplica_analise_emprego = true
    GROUP BY tempo_experiencia_ti
    ORDER BY CASE tempo_experiencia_ti {case_ordem_exp} ELSE 99 END ASC
""")
resultado_p2_2_1.show(truncate=False)

pdf_p2_2_1 = resultado_p2_2_1.toPandas()

# Aplica a quebra de linha nos textos longos da experiência em TI
pdf_p2_2_1['tempo_experiencia_ti_formatado'] = pdf_p2_2_1['tempo_experiencia_ti'].apply(
    lambda x: textwrap.fill(str(x), width=30)
)

grafico_barh(pdf_p2_2_1, 'tempo_experiencia_ti_formatado', 'salario_medio_estimado',
             'Salário médio estimado por tempo de experiência em TI', 'Salário médio estimado (R$)')
# Out:
# +--------------------------------------+----------------------+
# |tempo_experiencia_dados               |salario_medio_estimado|
# +--------------------------------------+----------------------+
# |Não tenho experiência na área de dados|6528.0                |
# |Menos de 1 ano                        |4328.0                |
# |de 1 a 2 anos                         |6183.0                |
# |de 3 a 4 anos                         |9774.0                |
# |de 5 a 6 anos                         |13516.0               |
# |de 7 a 10 anos                        |16042.0               |
# |Mais de 10 anos                       |18977.0               |
# +--------------------------------------+----------------------+
# +-------------------------------------------------------------------------------------------------------+----------------------+
# |tempo_experiencia_ti                                                                                   |salario_medio_estimado|
# +-------------------------------------------------------------------------------------------------------+----------------------+
# |Não tive experiência na área de TI/Engenharia de Software antes de começar a trabalhar na área de dados|9277.0                |
# |Menos de 1 ano                                                                                         |8796.0                |
# |de 1 a 2 anos                                                                                          |10390.0               |
# |de 3 a 4 anos                                                                                          |12198.0               |
# |de 5 a 6 anos                                                                                          |12396.0               |
# |de 7 a 10 anos                                                                                         |14085.0               |
# |Mais de 10 anos                                                                                        |16170.0               |
# +-------------------------------------------------------------------------------------------------------+----------------------+

# %% [markdown]
# **3. Existe diferença significativa de remuneração entre profissionais que migraram de TI para dados e os que iniciaram diretamente em dados?**

# %%
resultado_p2_3 = spark.sql("""
    SELECT
        CASE
            WHEN tempo_experiencia_ti =
                'Não tive experiência na área de TI/Engenharia de Software antes de começar a trabalhar na área de dados'
                THEN 'Começou direto em dados'
            ELSE 'Migrou de TI'
        END AS origem,
        ROUND(AVG(faixa_salarial_num), 0) AS salario_medio_estimado,
        COUNT(*) AS total
    FROM state_of_data_2023_num
    WHERE aplica_analise_emprego = true
      AND tempo_experiencia_ti IS NOT NULL
    GROUP BY 1
    ORDER BY total DESC
""")

resultado_p2_3.show(truncate=False)

pdf_p2_3 = resultado_p2_3.toPandas()
grafico_barh(pdf_p2_3, 'origem', 'salario_medio_estimado',
             'Salário médio estimado por origem na área de dados', 'Salário médio estimado (R$)')
# Out:
# +-----------------------+----------------------+-----+
# |origem                 |salario_medio_estimado|total|
# +-----------------------+----------------------+-----+
# |Migrou de TI           |11438.0               |2689 |
# |Começou direto em dados|9277.0                |2064 |
# +-----------------------+----------------------+-----+

# %% [markdown]
# **4. Qual é a relação entre senioridade e remuneração por função (Data Engineer, Data Analytics, Data Science)?**

# %%
import textwrap
import pandas as pd

# 1. Executa a consulta no PySpark
resultado_p2_4 = spark.sql("""
    SELECT cargo_atual, nivel_senioridade, ROUND(AVG(faixa_salarial_num), 0) AS salario_medio_estimado
    FROM state_of_data_2023_num
    WHERE aplica_analise_emprego = true AND aplica_analise_tecnica = true
      AND cargo_atual IN (
          'Engenheiro de Dados/Arquiteto de Dados/Data Engineer/Data Architect',
          'Analista de Dados/Data Analyst',
          'Cientista de Dados/Data Scientist'
      )
    GROUP BY cargo_atual, nivel_senioridade
""")
resultado_p2_4.show(truncate=False)
pdf_p1_1_4 = resultado_p2_4.toPandas()

# 2. Simplifica o nome dos cargos para o gráfico não ficar poluído
mapeamento_cargos = {
    'Analista de Dados/Data Analyst': 'Analista de Dados',
    'Cientista de Dados/Data Scientist': 'Cientista de Dados',
    'Engenheiro de Dados/Arquiteto de Dados/Data Engineer/Data Architect': 'Engenheiro de Dados'
}
pdf_p1_1_4['cargo_curto'] = pdf_p1_1_4['cargo_atual'].map(mapeamento_cargos)

# 3. Garante a ordem lógica da senioridade (Júnior -> Pleno -> Sênior)
pdf_p1_1_4['nivel_senioridade'] = pd.Categorical(pdf_p1_1_4['nivel_senioridade'], categories=ordem_senioridade, ordered=True)
pdf_p1_1_4 = pdf_p1_1_4.sort_values(['cargo_curto', 'nivel_senioridade'])

# 4. Cria a coluna combinada e aplica a quebra de linha
pdf_p1_1_4['cargo_senioridade'] = pdf_p1_1_4['cargo_curto'] + ' - ' + pdf_p1_1_4['nivel_senioridade'].astype(str)
pdf_p1_1_4['cargo_senioridade_formatado'] = pdf_p1_1_4['cargo_senioridade'].apply(lambda x: textwrap.fill(x, width=30))

# 5. Plota o gráfico com as 9 barras individuais
grafico_barh(pdf_p1_1_4, 'cargo_senioridade_formatado', 'salario_medio_estimado',
             'Salário médio estimado por cargo e nível de senioridade 2023', 'Salário médio estimado (R$)')
# Out:
# +-------------------------------------------------------------------+-----------------+----------------------+
# |cargo_atual                                                        |nivel_senioridade|salario_medio_estimado|
# +-------------------------------------------------------------------+-----------------+----------------------+
# |Analista de Dados/Data Analyst                                     |Pleno            |6775.0                |
# |Engenheiro de Dados/Arquiteto de Dados/Data Engineer/Data Architect|Sênior           |16365.0               |
# |Cientista de Dados/Data Scientist                                  |Pleno            |8860.0                |
# |Cientista de Dados/Data Scientist                                  |Sênior           |15616.0               |
# |Analista de Dados/Data Analyst                                     |Júnior           |3794.0                |
# |Analista de Dados/Data Analyst                                     |Sênior           |11089.0               |
# |Engenheiro de Dados/Arquiteto de Dados/Data Engineer/Data Architect|Pleno            |8966.0                |
# |Engenheiro de Dados/Arquiteto de Dados/Data Engineer/Data Architect|Júnior           |4476.0                |
# |Cientista de Dados/Data Scientist                                  |Júnior           |4902.0                |
# +-------------------------------------------------------------------+-----------------+----------------------+

# %% [markdown]
# **5. Quais são os objetivos de carreira mais citados na área de dados? (top 5)**

# %%
resultado_p2_5 = spark.sql("""
    SELECT objetivo_carreira, COUNT(*) AS total
    FROM state_of_data_2023
    WHERE aplica_analise_emprego = false and objetivo_carreira IS NOT NULL
    GROUP BY objetivo_carreira
    ORDER BY total DESC
""")
resultado_p2_5.show(truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |objetivo_carreira                                                                                                                                 |total|
# +--------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |Migração de carreira: Trabalho em outra área e busco recolocação na área de dados                                                                 |153  |
# |Preparação profissional: Estou buscando conhecimentos técnicos para no futuro assumir algum cargo na área de dados                                |150  |
# |Primeiro emprego: Estou tentando encontrar a primeira oportunidade na área de dados                                                               |135  |
# |Apenas conhecimentos: Busco conhecimentos em dados para utilizar na minha área de atuação (não trabalho na área de dados)                         |38   |
# |Já trabalho na área de dados                                                                                                                      |2    |
# |Atualmente já trabalho com dados                                                                                                                  |1    |
# |Já atuo na área de dados                                                                                                                          |1    |
# |Crescimento profissional (já atuo na área de dados)                                                                                               |1    |
# |Eu trabalho com dados                                                                                                                             |1    |
# |Aprendizado                                                                                                                                       |1    |
# |Já entrei na área. Meu objetivo é, então, crescer dentro da engenharia de dados.                                                                  |1    |
# |Crescimento na área                                                                                                                               |1    |
# |Não tenho objetivo nessa area                                                                                                                     |1    |
# |Já migrei de outra área para Dados, busco me qualificar para posições de liderança                                                                |1    |
# |Já trabalho há anos na área de dados e busco aperfeiçoamento constante.                                                                           |1    |
# |Buscando desenvolvimento técnico para conseguir uma nova oportunidade na área de Dados e continuar crescendo a posições de liderança              |1    |
# |Trabalhar para o exterior.                                                                                                                        |1    |
# |Recolocação em cargo de gestão                                                                                                                    |1    |
# |Ja atuo na área e quero me tornar especialista em Engenharia de Dados                                                                             |1    |
# |Aprofundamento em Gov de dados. Trabalgei por 25 anos na area de dados. Agora aposentada querome manter atualizada e colaborar onde for necessario|1    |
# +--------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# only showing top 20 rows

# %% [markdown]
# ## P3 — Qual é o cenário de diversidade de gênero nas carreiras de dados?

# %% [markdown]
# **1. Qual é a proporção de gênero entre os profissionais de dados?**

# %%
resultado_p3_1 = spark.sql("""
    SELECT genero, COUNT(*) AS total,
           ROUND(100.0 * COUNT(*) / SUM(COUNT(*)) OVER (), 1) AS percentual
    FROM state_of_data_2023
    GROUP BY genero
    ORDER BY total DESC
""")
resultado_p3_1.show(truncate=False)

pdf_p1_1_3 = resultado_p3_1.toPandas()
grafico_barh(pdf_p1_1_3, 'genero', 'total', 'Distribuição de Gênero 2023', 'Total')
# Out:
# +--------------------+-----+----------+
# |genero              |total|percentual|
# +--------------------+-----+----------+
# |Masculino           |3975 |75.1      |
# |Feminino            |1293 |24.4      |
# |Prefiro não informar|16   |0.3       |
# |Outro               |9    |0.2       |
# +--------------------+-----+----------+

# %% [markdown]
# **2. Existe gap salarial entre gêneros no mesmo cargo e senioridade?**

# %%
resultado_p3_2 = spark.sql("""
    SELECT cargo_atual, nivel_senioridade, genero, ROUND(AVG(faixa_salarial_num), 0) AS salario_medio_estimado
    FROM state_of_data_2023_num
    WHERE aplica_analise_emprego = true AND aplica_analise_tecnica = true
    GROUP BY cargo_atual, nivel_senioridade, genero
    ORDER BY cargo_atual, nivel_senioridade, genero
""")
resultado_p3_2.show(100, truncate=False)
# Out:
# +-------------------------------------------------------------------+-----------------+--------------------+----------------------+
# |cargo_atual                                                        |nivel_senioridade|genero              |salario_medio_estimado|
# +-------------------------------------------------------------------+-----------------+--------------------+----------------------+
# |Analista de BI/BI Analyst                                          |Júnior           |Feminino            |3301.0                |
# |Analista de BI/BI Analyst                                          |Júnior           |Masculino           |3215.0                |
# |Analista de BI/BI Analyst                                          |Pleno            |Feminino            |6156.0                |
# |Analista de BI/BI Analyst                                          |Pleno            |Masculino           |6461.0                |
# |Analista de BI/BI Analyst                                          |Pleno            |Outro               |10000.0               |
# |Analista de BI/BI Analyst                                          |Sênior           |Feminino            |10182.0               |
# |Analista de BI/BI Analyst                                          |Sênior           |Masculino           |10046.0               |
# |Analista de Dados/Data Analyst                                     |Júnior           |Feminino            |3738.0                |
# |Analista de Dados/Data Analyst                                     |Júnior           |Masculino           |3802.0                |
# |Analista de Dados/Data Analyst                                     |Júnior           |Prefiro não informar|7000.0                |
# |Analista de Dados/Data Analyst                                     |Pleno            |Feminino            |6368.0                |
# |Analista de Dados/Data Analyst                                     |Pleno            |Masculino           |6936.0                |
# |Analista de Dados/Data Analyst                                     |Sênior           |Feminino            |11342.0               |
# |Analista de Dados/Data Analyst                                     |Sênior           |Masculino           |11021.0               |
# |Analista de Dados/Data Analyst                                     |Sênior           |Outro               |8500.0                |
# |Analista de Inteligência de Mercado/Market Intelligence            |Júnior           |Feminino            |2417.0                |
# |Analista de Inteligência de Mercado/Market Intelligence            |Júnior           |Masculino           |3400.0                |
# |Analista de Inteligência de Mercado/Market Intelligence            |Pleno            |Feminino            |7200.0                |
# |Analista de Inteligência de Mercado/Market Intelligence            |Pleno            |Masculino           |4950.0                |
# |Analista de Inteligência de Mercado/Market Intelligence            |Sênior           |Feminino            |10000.0               |
# |Analista de Inteligência de Mercado/Market Intelligence            |Sênior           |Masculino           |10900.0               |
# |Analista de Negócios/Business Analyst                              |Júnior           |Feminino            |3471.0                |
# |Analista de Negócios/Business Analyst                              |Júnior           |Masculino           |3865.0                |
# |Analista de Negócios/Business Analyst                              |Pleno            |Feminino            |6889.0                |
# |Analista de Negócios/Business Analyst                              |Pleno            |Masculino           |6167.0                |
# |Analista de Negócios/Business Analyst                              |Sênior           |Feminino            |9953.0                |
# |Analista de Negócios/Business Analyst                              |Sênior           |Masculino           |9422.0                |
# |Analista de Suporte/Analista Técnico                               |Júnior           |Feminino            |2688.0                |
# |Analista de Suporte/Analista Técnico                               |Júnior           |Masculino           |2694.0                |
# |Analista de Suporte/Analista Técnico                               |Pleno            |Feminino            |4250.0                |
# |Analista de Suporte/Analista Técnico                               |Pleno            |Masculino           |4324.0                |
# |Analista de Suporte/Analista Técnico                               |Sênior           |Feminino            |7300.0                |
# |Analista de Suporte/Analista Técnico                               |Sênior           |Masculino           |7600.0                |
# |Analytics Engineer                                                 |Júnior           |Feminino            |3167.0                |
# |Analytics Engineer                                                 |Júnior           |Masculino           |4542.0                |
# |Analytics Engineer                                                 |Pleno            |Feminino            |9833.0                |
# |Analytics Engineer                                                 |Pleno            |Masculino           |8583.0                |
# |Analytics Engineer                                                 |Pleno            |Outro               |5000.0                |
# |Analytics Engineer                                                 |Sênior           |Feminino            |13458.0               |
# |Analytics Engineer                                                 |Sênior           |Masculino           |14702.0               |
# |Cientista de Dados/Data Scientist                                  |Júnior           |Feminino            |5073.0                |
# |Cientista de Dados/Data Scientist                                  |Júnior           |Masculino           |4845.0                |
# |Cientista de Dados/Data Scientist                                  |Pleno            |Feminino            |8822.0                |
# |Cientista de Dados/Data Scientist                                  |Pleno            |Masculino           |8886.0                |
# |Cientista de Dados/Data Scientist                                  |Pleno            |Prefiro não informar|7500.0                |
# |Cientista de Dados/Data Scientist                                  |Sênior           |Feminino            |13657.0               |
# |Cientista de Dados/Data Scientist                                  |Sênior           |Masculino           |15888.0               |
# |Cientista de Dados/Data Scientist                                  |Sênior           |Prefiro não informar|31333.0               |
# |DBA/Administrador de Banco de Dados                                |Júnior           |Feminino            |2000.0                |
# |DBA/Administrador de Banco de Dados                                |Pleno            |Masculino           |6800.0                |
# |DBA/Administrador de Banco de Dados                                |Sênior           |Feminino            |12667.0               |
# |DBA/Administrador de Banco de Dados                                |Sênior           |Masculino           |15100.0               |
# |Data Product Manager/ Product Manager (PM/APM/DPM/GPM/PO)          |Júnior           |Feminino            |4250.0                |
# |Data Product Manager/ Product Manager (PM/APM/DPM/GPM/PO)          |Júnior           |Masculino           |7083.0                |
# |Data Product Manager/ Product Manager (PM/APM/DPM/GPM/PO)          |Pleno            |Feminino            |9750.0                |
# |Data Product Manager/ Product Manager (PM/APM/DPM/GPM/PO)          |Pleno            |Masculino           |9450.0                |
# |Data Product Manager/ Product Manager (PM/APM/DPM/GPM/PO)          |Sênior           |Feminino            |13048.0               |
# |Data Product Manager/ Product Manager (PM/APM/DPM/GPM/PO)          |Sênior           |Masculino           |12397.0               |
# |Desenvolvedor/ Engenheiro de Software/ Analista de Sistemas        |Júnior           |Feminino            |2792.0                |
# |Desenvolvedor/ Engenheiro de Software/ Analista de Sistemas        |Júnior           |Masculino           |3636.0                |
# |Desenvolvedor/ Engenheiro de Software/ Analista de Sistemas        |Pleno            |Feminino            |7800.0                |
# |Desenvolvedor/ Engenheiro de Software/ Analista de Sistemas        |Pleno            |Masculino           |7452.0                |
# |Desenvolvedor/ Engenheiro de Software/ Analista de Sistemas        |Sênior           |Feminino            |14100.0               |
# |Desenvolvedor/ Engenheiro de Software/ Analista de Sistemas        |Sênior           |Masculino           |14598.0               |
# |Economista                                                         |Júnior           |Masculino           |1500.0                |
# |Economista                                                         |Pleno            |Feminino            |7000.0                |
# |Economista                                                         |Pleno            |Masculino           |10000.0               |
# |Economista                                                         |Sênior           |Masculino           |18750.0               |
# |Engenheiro de Dados/Arquiteto de Dados/Data Engineer/Data Architect|Júnior           |Feminino            |3879.0                |
# |Engenheiro de Dados/Arquiteto de Dados/Data Engineer/Data Architect|Júnior           |Masculino           |4660.0                |
# |Engenheiro de Dados/Arquiteto de Dados/Data Engineer/Data Architect|Júnior           |Prefiro não informar|5250.0                |
# |Engenheiro de Dados/Arquiteto de Dados/Data Engineer/Data Architect|Pleno            |Feminino            |8698.0                |
# |Engenheiro de Dados/Arquiteto de Dados/Data Engineer/Data Architect|Pleno            |Masculino           |9044.0                |
# |Engenheiro de Dados/Arquiteto de Dados/Data Engineer/Data Architect|Sênior           |Feminino            |14890.0               |
# |Engenheiro de Dados/Arquiteto de Dados/Data Engineer/Data Architect|Sênior           |Masculino           |16577.0               |
# |Engenheiro de Machine Learning/ML Engineer/AI Engineer             |Júnior           |Feminino            |5000.0                |
# |Engenheiro de Machine Learning/ML Engineer/AI Engineer             |Júnior           |Masculino           |4589.0                |
# |Engenheiro de Machine Learning/ML Engineer/AI Engineer             |Pleno            |Feminino            |9000.0                |
# |Engenheiro de Machine Learning/ML Engineer/AI Engineer             |Pleno            |Masculino           |11660.0               |
# |Engenheiro de Machine Learning/ML Engineer/AI Engineer             |Pleno            |Outro               |7000.0                |
# |Engenheiro de Machine Learning/ML Engineer/AI Engineer             |Sênior           |Feminino            |21000.0               |
# |Engenheiro de Machine Learning/ML Engineer/AI Engineer             |Sênior           |Masculino           |17440.0               |
# |Engenheiro de Machine Learning/ML Engineer/AI Engineer             |Sênior           |Prefiro não informar|35000.0               |
# |Estatístico                                                        |Júnior           |Feminino            |1500.0                |
# |Estatístico                                                        |Júnior           |Masculino           |3208.0                |
# |Estatístico                                                        |Pleno            |Feminino            |10750.0               |
# |Estatístico                                                        |Pleno            |Masculino           |11000.0               |
# |Estatístico                                                        |Pleno            |Prefiro não informar|6000.0                |
# |Estatístico                                                        |Sênior           |Feminino            |18000.0               |
# |Estatístico                                                        |Sênior           |Masculino           |22375.0               |
# |Outra Opção                                                        |Júnior           |Feminino            |3471.0                |
# |Outra Opção                                                        |Júnior           |Masculino           |3570.0                |
# |Outra Opção                                                        |Júnior           |Outro               |1500.0                |
# |Outra Opção                                                        |Pleno            |Feminino            |6354.0                |
# |Outra Opção                                                        |Pleno            |Masculino           |5115.0                |
# |Outra Opção                                                        |Pleno            |Outro               |2500.0                |
# |Outra Opção                                                        |Sênior           |Feminino            |12500.0               |
# |Outra Opção                                                        |Sênior           |Masculino           |12278.0               |
# |Outras Engenharias (não inclui dev)                                |Júnior           |Feminino            |3250.0                |
# |Outras Engenharias (não inclui dev)                                |Júnior           |Masculino           |5063.0                |
# +-------------------------------------------------------------------+-----------------+--------------------+----------------------+
# only showing top 100 rows

# %% [markdown]
# **3. Como a representatividade de cor/raça/etnia se distribui entre níveis de senioridade?**

# %%
resultado_p3_3 = spark.sql("""
    SELECT nivel_senioridade, cor_raca_etnia, COUNT(*) AS total
    FROM state_of_data_2023
    WHERE aplica_analise_tecnica = true
    GROUP BY nivel_senioridade, cor_raca_etnia
    ORDER BY nivel_senioridade, total DESC
""")
resultado_p3_3.show(50, truncate=False)
# Out:
# +-----------------+--------------------+-----+
# |nivel_senioridade|cor_raca_etnia      |total|
# +-----------------+--------------------+-----+
# |Júnior           |Branca              |629  |
# |Júnior           |Parda               |289  |
# |Júnior           |Preta               |87   |
# |Júnior           |Amarela             |26   |
# |Júnior           |Prefiro não informar|10   |
# |Júnior           |Indígena            |4    |
# |Júnior           |Outra               |1    |
# |Pleno            |Branca              |882  |
# |Pleno            |Parda               |368  |
# |Pleno            |Preta               |99   |
# |Pleno            |Amarela             |32   |
# |Pleno            |Prefiro não informar|6    |
# |Pleno            |Outra               |3    |
# |Pleno            |Indígena            |2    |
# |Sênior           |Branca              |955  |
# |Sênior           |Parda               |302  |
# |Sênior           |Preta               |95   |
# |Sênior           |Amarela             |46   |
# |Sênior           |Prefiro não informar|13   |
# |Sênior           |Outra               |5    |
# |Sênior           |Indígena            |3    |
# +-----------------+--------------------+-----+

# %% [markdown]
# ## P4 — Quais tecnologias apresentam maior adoção entre os profissionais?

# %% [markdown]
# **1. Quais linguagens de programação são mais utilizadas no dia a dia?**

# %%
resultado_p4_1 = spark.sql("""
SELECT 'SQL' AS linguagem,
       SUM(CASE WHEN linguagens_trabalho__sql THEN 1 ELSE 0 END) AS total
FROM state_of_data_2023
WHERE aplica_analise_tecnica = true

UNION ALL

SELECT 'R',
       SUM(CASE WHEN linguagens_trabalho__r THEN 1 ELSE 0 END)
FROM state_of_data_2023
WHERE aplica_analise_tecnica = true

UNION ALL

SELECT 'Python',
       SUM(CASE WHEN linguagens_trabalho__python THEN 1 ELSE 0 END)
FROM state_of_data_2023
WHERE aplica_analise_tecnica = true

UNION ALL

SELECT 'C/C++/C#',
       SUM(CASE WHEN linguagens_trabalho__c_c_c THEN 1 ELSE 0 END)
FROM state_of_data_2023
WHERE aplica_analise_tecnica = true

UNION ALL

SELECT '.NET',
       SUM(CASE WHEN linguagens_trabalho__net THEN 1 ELSE 0 END)
FROM state_of_data_2023
WHERE aplica_analise_tecnica = true

UNION ALL

SELECT 'Java',
       SUM(CASE WHEN linguagens_trabalho__java THEN 1 ELSE 0 END)
FROM state_of_data_2023
WHERE aplica_analise_tecnica = true

UNION ALL

SELECT 'Julia',
       SUM(CASE WHEN linguagens_trabalho__julia THEN 1 ELSE 0 END)
FROM state_of_data_2023
WHERE aplica_analise_tecnica = true

UNION ALL

SELECT 'SAS/Stata',
       SUM(CASE WHEN linguagens_trabalho__sas_stata THEN 1 ELSE 0 END)
FROM state_of_data_2023
WHERE aplica_analise_tecnica = true

UNION ALL

SELECT 'VBA',
       SUM(CASE WHEN linguagens_trabalho__visual_basic_vba THEN 1 ELSE 0 END)
FROM state_of_data_2023
WHERE aplica_analise_tecnica = true

UNION ALL

SELECT 'Scala',
       SUM(CASE WHEN linguagens_trabalho__scala THEN 1 ELSE 0 END)
FROM state_of_data_2023
WHERE aplica_analise_tecnica = true

UNION ALL

SELECT 'Matlab',
       SUM(CASE WHEN linguagens_trabalho__matlab THEN 1 ELSE 0 END)
FROM state_of_data_2023
WHERE aplica_analise_tecnica = true

UNION ALL

SELECT 'Rust',
       SUM(CASE WHEN linguagens_trabalho__rust THEN 1 ELSE 0 END)
FROM state_of_data_2023
WHERE aplica_analise_tecnica = true

UNION ALL

SELECT 'PHP',
       SUM(CASE WHEN linguagens_trabalho__php THEN 1 ELSE 0 END)
FROM state_of_data_2023
WHERE aplica_analise_tecnica = true

UNION ALL

SELECT 'JavaScript',
       SUM(CASE WHEN linguagens_trabalho__javascript THEN 1 ELSE 0 END)
FROM state_of_data_2023
WHERE aplica_analise_tecnica = true

ORDER BY total DESC
""")

resultado_p4_1.show(20, truncate=False)

pdf_p4_1 = resultado_p4_1.toPandas()
grafico_barh(pdf_p4_1, 'linguagem', 'total', 'Linguagens de Programação mais utilizadas 2023', 'Total')
# Out:
# +----------+-----+
# |linguagem |total|
# +----------+-----+
# |SQL       |3156 |
# |Python    |2825 |
# |R         |408  |
# |Java      |355  |
# |VBA       |285  |
# |JavaScript|282  |
# |SAS/Stata |151  |
# |Scala     |131  |
# |C/C++/C#  |70   |
# |PHP       |56   |
# |.NET      |40   |
# |Matlab    |30   |
# |Julia     |8    |
# |Rust      |7    |
# +----------+-----+

# %% [markdown]
# **2. Qual provedor de cloud predomina e qual é o preferido?**

# %%
resultado_p4_2 = spark.sql("""
SELECT 'AWS' AS cloud,
       SUM(CASE WHEN cloud__amazon_web_services_aws THEN 1 ELSE 0 END) AS total
FROM state_of_data_2023
WHERE aplica_analise_tecnica = true

UNION ALL

SELECT 'GCP',
       SUM(CASE WHEN cloud__google_cloud_gcp THEN 1 ELSE 0 END)
FROM state_of_data_2023
WHERE aplica_analise_tecnica = true

UNION ALL

SELECT 'Azure',
       SUM(CASE WHEN cloud__azure_microsoft THEN 1 ELSE 0 END)
FROM state_of_data_2023
WHERE aplica_analise_tecnica = true

UNION ALL

SELECT 'Oracle Cloud',
       SUM(CASE WHEN cloud__oracle_cloud THEN 1 ELSE 0 END)
FROM state_of_data_2023
WHERE aplica_analise_tecnica = true

UNION ALL

SELECT 'On Premise/Nenhuma',
       SUM(CASE WHEN cloud__servidores_on_premise_nao_utilizamos_cloud THEN 1 ELSE 0 END)
FROM state_of_data_2023
WHERE aplica_analise_tecnica = true

ORDER BY total DESC
""")

resultado_p4_2.show(truncate=False)

pdf_p4_2 = resultado_p4_2.toPandas()
grafico_barh(pdf_p4_2, 'cloud', 'total', 'Plataformas de Cloud mais utilizadas 2023', 'Total')
# Out:
# +------------------+-----+
# |cloud             |total|
# +------------------+-----+
# |Azure             |1529 |
# |GCP               |1141 |
# |AWS               |1106 |
# |On Premise/Nenhuma|582  |
# |Oracle Cloud      |154  |
# +------------------+-----+

# %% [markdown]
# **Detalhe que preciso lembrar aqui:** uso `SUM(CASE WHEN coluna THEN 1 ELSE 0
# END)` em vez de `COUNT(coluna)`. Isso não é só estilo - é necessário porque
# essas colunas viraram boolean (`true`/`false`), e `COUNT` conta qualquer valor
# não-nulo, incluindo os `false`. Se eu usasse `COUNT`, ia contar todo mundo que
# respondeu a pergunta de linguagens, não só quem realmente marcou aquela
# linguagem específica mudando o resultado

# %% [markdown]
# ## P5 — Qual é o índice de adoção de Inteligência Artificial e seu impacto?

# %% [markdown]
# **1. Qual proporção de empresas trata IA Generativa/LLMs como prioridade?**

# %%
resultado_p5_1 = spark.sql("""
    SELECT ia_prioridade, COUNT(*) AS total,
           ROUND(100.0 * COUNT(*) / SUM(COUNT(*)) OVER (), 1) AS percentual
    FROM state_of_data_2023
    WHERE ia_prioridade IS NOT NULL
    GROUP BY ia_prioridade
    ORDER BY total DESC
""")
resultado_p5_1.show(truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------+-----+----------+
# |ia_prioridade                                                                                                                               |total|percentual|
# +--------------------------------------------------------------------------------------------------------------------------------------------+-----+----------+
# |Mais ou menos... É uma das várias iniciativas que estamos impulsionando, mas não é uma prioridade (iniciativas isoladas e pouco foco).      |275  |30.7      |
# |Não é uma iniciativa que estamos focando e não tem sido uma prioridade.                                                                     |258  |28.8      |
# |Sim, está entre nossas principais prioridades para os próximos 2-4 anos (com discussões de iniciativas e orçamentos de curto a médio prazo).|214  |23.9      |
# |Sim, é nossa principal prioridade como empresa (com foco executivo significativo e alocação de orçamento relevante).                        |110  |12.3      |
# |Não sei opinar sobre esse assunto.                                                                                                          |39   |4.4       |
# +--------------------------------------------------------------------------------------------------------------------------------------------+-----+----------+

# %% [markdown]
# **2. Quem paga pela IA usada no trabalho, o profissional ou a empresa?**

# %%
resultado_p5_2 = spark.sql("""
    SELECT 'Não usa' AS uso_pessoal, SUM(CASE WHEN ia_uso_pessoal__nao_uso_solucoes_de_ai_generativa_com_foco_em_produtividade THEN 1 ELSE 0 END) AS total FROM state_of_data_2023 WHERE aplica_analise_tecnica = true
    UNION ALL SELECT 'Usa grátis', SUM(CASE WHEN ia_uso_pessoal__uso_solucoes_gratuitas_de_ai_generativa_com_foco_em_produtividade THEN 1 ELSE 0 END) FROM state_of_data_2023 WHERE aplica_analise_tecnica = true
    UNION ALL SELECT 'Usa e paga', SUM(CASE WHEN ia_uso_pessoal__uso_e_pago_pelas_solucoes_de_ai_generativa_com_foco_em_produtividade THEN 1 ELSE 0 END) FROM state_of_data_2023 WHERE aplica_analise_tecnica = true
    UNION ALL SELECT 'Empresa paga', SUM(CASE WHEN ia_uso_pessoal__a_empresa_que_trabalho_paga_pelas_solucoes_de_ai_generativa_com_foco_em_produtividade THEN 1 ELSE 0 END) FROM state_of_data_2023 WHERE aplica_analise_tecnica = true
    UNION ALL SELECT 'Usa Copilot', SUM(CASE WHEN ia_uso_pessoal__uso_solucoes_do_tipo_copilot THEN 1 ELSE 0 END) FROM state_of_data_2023 WHERE aplica_analise_tecnica = true
    ORDER BY total DESC
""")
resultado_p5_2.show(truncate=False)
grafico_barh(resultado_p5_2.toPandas(), 'uso_pessoal', 'total', 'Uso pessoal de IA generativa 2023', 'Total')
# Out:
# +------------+-----+
# |uso_pessoal |total|
# +------------+-----+
# |Usa grátis  |2401 |
# |Não usa     |744  |
# |Usa Copilot |444  |
# |Usa e paga  |261  |
# |Empresa paga|240  |
# +------------+-----+

# %% [markdown]
# ## P6 — Existem diferenças relevantes entre regiões, senioridades ou modelos de trabalho?

# %% [markdown]
# **1. Como a faixa salarial varia entre regiões do Brasil?**

# %% [markdown]
# **Achado ao revisar o notebook do início ao fim:** essa célula do gráfico usa
# `resultado_p6_1`, mas em nenhuma célula anterior essa variável é criada - ela
# só tinha output porque rodou em algum momento com uma consulta que não ficou
# salva no notebook (provavelmente se perdeu numa reorganização de célula). Se
# alguém rodar tudo do zero (`Restart & Run All`), essa célula quebra com
# `NameError`. Recriando a consulta que falta, seguindo o mesmo padrão das
# outras (`aplica_analise_emprego`, `aplica_analise_tecnica`, `faixa_salarial_num`)
# e já juntando região com senioridade - que é exatamente o cuidado de viés de
# composição que usamos lá na Silver (P6 e P3): comparar salário só por região,
# sem abrir por senioridade, pode confundir "a região paga mais" com "a região
# tem mais gente sênior".

# %%
resultado_p6_1 = spark.sql("""
    SELECT regiao_atual, nivel_senioridade,
           ROUND(AVG(faixa_salarial_num), 0) AS salario_medio_estimado, COUNT(*) AS total
    FROM state_of_data_2023_num
    WHERE aplica_analise_emprego = true AND aplica_analise_tecnica = true
      AND regiao_atual IS NOT NULL
      AND nivel_senioridade IN ('Júnior', 'Pleno', 'Sênior')
    GROUP BY regiao_atual, nivel_senioridade
    ORDER BY regiao_atual, nivel_senioridade
""")
resultado_p6_1.show(30, truncate=False)
# Out:
# +------------+-----------------+----------------------+-----+
# |regiao_atual|nivel_senioridade|salario_medio_estimado|total|
# +------------+-----------------+----------------------+-----+
# |Centro-oeste|Júnior           |4099.0                |76   |
# |Centro-oeste|Pleno            |7994.0                |80   |
# |Centro-oeste|Sênior           |14297.0               |91   |
# |Nordeste    |Júnior           |3434.0                |141  |
# |Nordeste    |Pleno            |6674.0                |168  |
# |Nordeste    |Sênior           |13570.0               |121  |
# |Norte       |Júnior           |4548.0                |21   |
# |Norte       |Pleno            |6222.0                |27   |
# |Norte       |Sênior           |12150.0               |10   |
# |Sudeste     |Júnior           |3897.0                |590  |
# |Sudeste     |Pleno            |7578.0                |807  |
# |Sudeste     |Sênior           |13367.0               |901  |
# |Sul         |Júnior           |3899.0                |198  |
# |Sul         |Pleno            |7234.0                |286  |
# |Sul         |Sênior           |13257.0               |263  |
# +------------+-----------------+----------------------+-----+

# %%
import seaborn as sns

# 1. Prepara os dados
pdf_p1_1_6 = resultado_p6_1.toPandas()

# 2. Define a nova ordem desejada (Sênior primeiro, depois Pleno e Júnior)
ordem_senioridade_grafico = list(reversed(ordem_senioridade))

# 3. Define as cores associadas a cada nível
paleta_senioridade = {
    "Sênior": "#08306B",  # Azul escuro
    "Pleno": "#2171B5",  # Azul médio
    "Júnior": "#6BAED6",  # Azul claro
}

# 4. Plota o gráfico agrupado
plt.figure(figsize=(11, 6))

ax = sns.barplot(
    data=pdf_p1_1_6,
    y="regiao_atual",
    x="salario_medio_estimado",
    hue="nivel_senioridade",
    hue_order=ordem_senioridade_grafico,  # Define a ordem visual das barras e da legenda
    palette=paleta_senioridade,
)

# 5. Ajustes de títulos e eixos
plt.title(
    "Salário médio estimado por região e nível de senioridade 2023",
    fontsize=12,
    fontweight="bold",
    pad=15,
)
plt.xlabel("Salário médio estimado (R$)")
plt.ylabel("Região")
plt.grid(axis="x", linestyle="--", alpha=0.4)

# 6. Posiciona a legenda fora da área de plotagem (à direita)
plt.legend(
    title="Senioridade", bbox_to_anchor=(1.02, 1), loc="upper left", borderaxespad=0
)

sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# **2. Existe diferença salarial entre modelos de trabalho (remoto vs presencial vs híbrido)?**

# %%
resultado_p6_2 = spark.sql("""
    SELECT nivel_senioridade, modelo_trabalho_atual,
           ROUND(AVG(faixa_salarial_num), 0) AS salario_medio_estimado, COUNT(*) AS total
    FROM state_of_data_2023_num
    WHERE aplica_analise_emprego = true AND aplica_analise_tecnica = true
    GROUP BY nivel_senioridade, modelo_trabalho_atual
    ORDER BY nivel_senioridade, salario_medio_estimado DESC
""")
resultado_p6_2.show(30, truncate=False)
# Out:
# +-----------------+--------------------------------------------------------------------------------------------------------------+----------------------+-----+
# |nivel_senioridade|modelo_trabalho_atual                                                                                         |salario_medio_estimado|total|
# +-----------------+--------------------------------------------------------------------------------------------------------------+----------------------+-----+
# |Júnior           |Modelo híbrido flexível (o funcionário tem liberdade para escolher quando estar no escritório presencialmente)|4554.0                |182  |
# |Júnior           |Modelo híbrido com dias fixos de trabalho presencial                                                          |4030.0                |186  |
# |Júnior           |Modelo 100% remoto                                                                                            |4011.0                |395  |
# |Júnior           |Modelo 100% presencial                                                                                        |3293.0                |283  |
# |Pleno            |Modelo híbrido flexível (o funcionário tem liberdade para escolher quando estar no escritório presencialmente)|8156.0                |257  |
# |Pleno            |Modelo 100% remoto                                                                                            |7934.0                |673  |
# |Pleno            |Modelo híbrido com dias fixos de trabalho presencial                                                          |7287.0                |238  |
# |Pleno            |Modelo 100% presencial                                                                                        |5919.0                |224  |
# |Sênior           |Modelo 100% remoto                                                                                            |14732.0               |796  |
# |Sênior           |Modelo híbrido flexível (o funcionário tem liberdade para escolher quando estar no escritório presencialmente)|13253.0               |289  |
# |Sênior           |Modelo híbrido com dias fixos de trabalho presencial                                                          |12235.0               |206  |
# |Sênior           |Modelo 100% presencial                                                                                        |10305.0               |128  |
# +-----------------+--------------------------------------------------------------------------------------------------------------+----------------------+-----+

# %% [markdown]
# **3. Nível de ensino/formação x faixa salarial**

# %%
resultado_p6_3 = spark.sql("""
    SELECT nivel_ensino, ROUND(AVG(faixa_salarial_num), 0) AS salario_medio_estimado, COUNT(*) AS total
    FROM state_of_data_2023_num
    WHERE aplica_analise_emprego = true
    GROUP BY nivel_ensino
    ORDER BY salario_medio_estimado DESC
""")
resultado_p6_3.show(truncate=False)

pdf_p6_3 = resultado_p6_3.toPandas()
grafico_barh(pdf_p6_3, 'nivel_ensino', 'salario_medio_estimado',
             'Salário médio estimado por nível de ensino 2023', 'Salário médio estimado (R$)')
# Out:
# +--------------------------+----------------------+-----+
# |nivel_ensino              |salario_medio_estimado|total|
# +--------------------------+----------------------+-----+
# |Doutorado ou Phd          |14955.0               |184  |
# |Mestrado                  |14223.0               |606  |
# |Pós-graduação             |11866.0               |1701 |
# |Prefiro não informar      |10208.0               |6    |
# |Graduação/Bacharelado     |9241.0                |1641 |
# |Não tenho graduação formal|9018.0                |83   |
# |Estudante de Graduação    |4466.0                |532  |
# +--------------------------+----------------------+-----+

# %% [markdown]
# **4. Qual seria a atitude dos profissionais diante de um retorno presencial obrigatório?**

# %%
import textwrap

resultado_p6_4 = spark.sql("""
    SELECT atitude_retorno_presencial, COUNT(*) AS total
    FROM state_of_data_2023
    WHERE aplica_analise_emprego = true
    AND atitude_retorno_presencial IS NOT NULL
    GROUP BY atitude_retorno_presencial
    ORDER BY total DESC
""")

resultado_p6_4.show(truncate=False)

pdf_p6_4 = resultado_p6_4.toPandas()

# Aplica a quebra de linha preservando o \n (limite de 25-30 caracteres)
pdf_p6_4['atitude_retorno_formatada'] = pdf_p6_4['atitude_retorno_presencial'].apply(
    lambda x: textwrap.fill(str(x), width=25)
)

grafico_barh(pdf_p6_4, 'atitude_retorno_formatada', 'total',
             'Atitude em relação ao retorno presencial 2023', 'Quantidade de pessoas')
# Out:
# +-----------------------------------------------------------+-----+
# |atitude_retorno_presencial                                 |total|
# +-----------------------------------------------------------+-----+
# |Vou procurar outra oportunidade no modelo híbrido ou remoto|2068 |
# |Vou procurar outra oportunidade no modelo 100% remoto      |1487 |
# |Vou aceitar e retornar ao modelo 100% presencial           |1198 |
# +-----------------------------------------------------------+-----+

# %% [markdown]
# ## P7 — Quais oportunidades e desafios podem ser identificados para empresas que desejam investir em Dados e IA?

# %% [markdown]
# **1. Qual é o nível de satisfação geral dos profissionais de dados?**

# %%
resultado_p7_1 = spark.sql("""
    SELECT
        CASE
            WHEN satisfeito_empresa = true THEN 'Satisfeito'
            WHEN satisfeito_empresa = false THEN 'Insatisfeito'
        END AS satisfeito_empresa,
        COUNT(*) AS total,
        ROUND(
            100.0 * COUNT(*) /
            SUM(COUNT(*)) OVER (),
            1
        ) AS percentual
    FROM state_of_data_2023
    WHERE aplica_analise_emprego = true
      AND satisfeito_empresa IS NOT NULL
    GROUP BY 1
    ORDER BY total DESC
""")
resultado_p7_1.show(truncate=False)

pdf_p7_1 = resultado_p7_1.toPandas()

grafico_barh(pdf_p7_1, 'satisfeito_empresa', 'total', 
             'Satisfação com a Empresa 2023', 'Quantidade de pessoas')
# Out:
# +------------------+-----+----------+
# |satisfeito_empresa|total|percentual|
# +------------------+-----+----------+
# |Satisfeito        |3420 |72.0      |
# |Insatisfeito      |1333 |28.0      |
# +------------------+-----+----------+

# %% [markdown]
# **2. Qual proporção planeja mudar de emprego nos próximos 6 meses?**

# %%
import textwrap


resultado_p7_2 = spark.sql("""
    SELECT pretende_mudar_emprego, COUNT(*) AS total,
           ROUND(100.0 * COUNT(*) / SUM(COUNT(*)) OVER (), 1) AS percentual
    FROM state_of_data_2023
    WHERE aplica_analise_emprego = true
    and pretende_mudar_emprego IS NOT NULL
    GROUP BY pretende_mudar_emprego
    ORDER BY total DESC
""")

resultado_p7_2.show(truncate=False)

pdf_p7_2 = resultado_p7_2.toPandas()

pdf_p7_2['pretende_mudar_emprego_formatado'] = pdf_p7_2['pretende_mudar_emprego'].apply(
    lambda x: textwrap.fill(str(x), width=30)
)

grafico_barh(pdf_p7_2, 'pretende_mudar_emprego_formatado', 'total', 
             'Pretensão de mudança de emprego 2023', 'Quantidade de pessoas')
# Out:
# +-----------------------------------------------------------------------+-----+----------+
# |pretende_mudar_emprego                                                 |total|percentual|
# +-----------------------------------------------------------------------+-----+----------+
# |Não estou buscando, mas me considero aberto a outras oportunidades     |1761 |37.1      |
# |Estou em busca de oportunidades dentro ou fora do Brasil               |1338 |28.2      |
# |Não estou buscando e não pretendo mudar de emprego nos próximos 6 meses|1210 |25.5      |
# |Estou em busca de oportunidades, mas apenas fora do Brasil             |444  |9.3       |
# +-----------------------------------------------------------------------+-----+----------+

# %% [markdown]
# **3. Quais são os desafios mais citados por gestores de dados?**

# %%
resultado_p7_3 = spark.sql("""
    SELECT desafio, total
    FROM (
        SELECT 
            SUM(CAST(desafios_gestor__a_contratar_novos_talentos AS INT)) AS `Contratar talentos`,
            SUM(CAST(desafios_gestor__b_reter_talentos AS INT)) AS `Reter talentos`,
            SUM(CAST(desafios_gestor__c_convencer_a_empresa_a_aumentar_os_investimentos_na_area_de_dados AS INT)) AS `Convencer a empresa a investir`,
            SUM(CAST(desafios_gestor__d_gestao_de_equipes_no_ambiente_remoto AS INT)) AS `Gestão de equipes remotas`,
            SUM(CAST(desafios_gestor__g_conseguir_processar_e_armazenar_um_alto_volume_de_dados AS INT)) AS `Processar/armazenar alto volume`,
            SUM(CAST(desafios_gestor__h_conseguir_gerar_valor_para_as_areas_de_negocios_atraves_de_estudos_e_experimentos AS INT)) AS `Gerar valor para o negócio`,
            SUM(CAST(desafios_gestor__i_desenvolver_e_manter_modelos_machine_learning_em_producao AS INT)) AS `Modelos de ML em produção`,
            SUM(CAST(desafios_gestor__dividir_o_tempo_entre_entregas_tecnicas_e_gestao AS INT)) AS `Dividir tempo técnico/gestão`
        FROM state_of_data_2023
        WHERE aplica_analise_gestor = true
    )
    UNPIVOT (
        total FOR desafio IN (
            `Contratar talentos`, 
            `Reter talentos`, 
            `Convencer a empresa a investir`, 
            `Gestão de equipes remotas`, 
            `Processar/armazenar alto volume`, 
            `Gerar valor para o negócio`, 
            `Modelos de ML em produção`, 
            `Dividir tempo técnico/gestão`
        )
    )
    ORDER BY total DESC
""")
resultado_p7_3.show(truncate=False)

pdf_p7_3 = resultado_p7_3.toPandas()
grafico_barh(pdf_p7_3, 'desafio', 'total',
             'Principais desafios dos gestores de dados 2023', 'Quantidade de pessoas')
# Out:
# +-------------------------------+-----+
# |desafio                        |total|
# +-------------------------------+-----+
# |Gerar valor para o negócio     |267  |
# |Dividir tempo técnico/gestão   |257  |
# |Convencer a empresa a investir |148  |
# |Contratar talentos             |142  |
# |Reter talentos                 |116  |
# |Gestão de equipes remotas      |75   |
# |Modelos de ML em produção      |69   |
# |Processar/armazenar alto volume|46   |
# +-------------------------------+-----+

# %% [markdown]
# ## 4. Exportando as tabelas Gold
#
# Com todas as perguntas respondidas, chegou a hora de persistir cada resultado
# como uma tabela Gold - assim quem for montar a apresentação executiva (ou
# plugar isso num QuickSight/Athena) não precisa rodar Spark de novo, só ler o
# Parquet pronto.
#
# Decidi exportar **uma tabela por sub-pergunta**, não só uma tabela "geral" por
# pergunta principal - cada sub-pergunta tem um agrupamento (`GROUP BY`)
# diferente, então forçar tudo numa tabela só ia significar ou perder detalhe ou
# misturar grãos diferentes na mesma tabela (o que complica muito a leitura
# depois). Em compensação, organizo essas tabelas dentro de **7 pastas**, uma
# por pergunta principal do desafio - assim quem for procurar "os dados de
# diversidade de gênero" sabe exatamente onde olhar, mesmo tendo várias tabelas
# lá dentro.
#
# Os caminhos abaixo são locais pra eu testar - na submissão final do desafio,
# troco pelo caminho do bucket S3 do grupo, algo tipo
# `s3://<bucket-do-grupo>/gold/p3_diversidade/gap_salarial_genero/`.

# %%
from utils.config import CAMINHO_GOLD_BASE

ANO_PESQUISA = 2023 # vinicius e maycon substituam aqui esse número pro ano da base que analisou

tabelas_por_pergunta = {
    "p1_estrutura_mercado": {
        "situacao_trabalho": resultado_p1_1,
        "setor_top10": resultado_p1_2,
        "distribuicao_cargos": resultado_p1_3,
        "distribuicao_senioridade": resultado_p1_4,
        "percentual_gestores": resultado_p1_5,
        "experiencia_x_senioridade": resultado_p1_6,
        "modelo_trabalho_atual": resultado_p1_7,
        "modelo_trabalho_ideal": resultado_p1_7_1,
        "porte_empresa": resultado_p1_8,
    },
    "p2_perfis_valorizados": {
        "salario_por_cargo_senioridade": resultado_p2_1,
        "salario_por_experiencia_dados": resultado_p2_2,
        "salario_por_experiencia_ti": resultado_p2_2_1,
        "salario_migracao_ti": resultado_p2_3,
        "salario_por_funcao_senioridade": resultado_p2_4,
        "objetivos_carreira_top5": resultado_p2_5,
    },
    "p3_diversidade": {
        "proporcao_genero": resultado_p3_1,
        "gap_salarial_genero": resultado_p3_2,
        "raca_por_senioridade": resultado_p3_3,
    },
    "p4_tecnologias": {
        "linguagens_mais_usadas": resultado_p4_1,
        "cloud_predominante": resultado_p4_2,
    },
    "p5_ia_generativa": {
        "prioridade_ia_empresa": resultado_p5_1,
        "quem_paga_ia": resultado_p5_2,
    },
    "p6_diferencas_regionais": {
        "salario_por_regiao_senioridade": resultado_p6_1,
        "salario_por_modelo_trabalho": resultado_p6_2,
        "salario_por_nivel_ensino": resultado_p6_3,
        "atitude_retorno_presencial": resultado_p6_4,
    },
    "p7_oportunidades_desafios": {
        "satisfacao_geral": resultado_p7_1,
        "intencao_troca_emprego": resultado_p7_2,
        "desafios_gestores": resultado_p7_3,
    },
}

# só sobrescreve a partição do próprio ano na hora de gravar - sem isso, "overwrite"
# apaga a pasta inteira (todos os anos), não só a partição que estou escrevendo agora
spark.conf.set(
    "spark.sql.sources.partitionOverwriteMode",
    "dynamic"
)

for pasta, tabelas in tabelas_por_pergunta.items():

    for nome_tabela, df_resultado in tabelas.items():

        caminho = CAMINHO_GOLD_BASE / pasta / nome_tabela

        (
            df_resultado
            .withColumn("ano_pesquisa", F.lit(ANO_PESQUISA))
            .write
            .mode("overwrite")
            .partitionBy("ano_pesquisa")
            .parquet(str(caminho))
        )

    print(
        f"{pasta}: {len(tabelas)} tabela(s) exportada(s)"
    )

total_tabelas = sum(
    len(tabelas)
    for tabelas in tabelas_por_pergunta.values()
)

print(
    f"\nTotal: {total_tabelas} tabelas Gold exportadas."
)

print(
    f"Partição: ano_pesquisa={ANO_PESQUISA}"
)
# Out:
# p1_estrutura_mercado: 9 tabela(s) exportada(s)
# p2_perfis_valorizados: 6 tabela(s) exportada(s)
# p3_diversidade: 3 tabela(s) exportada(s)
# p4_tecnologias: 2 tabela(s) exportada(s)
# p5_ia_generativa: 2 tabela(s) exportada(s)
# p6_diferencas_regionais: 4 tabela(s) exportada(s)
# p7_oportunidades_desafios: 3 tabela(s) exportada(s)
#
# Total: 29 tabelas Gold exportadas.
# Partição: ano_pesquisa=2023

# %% [markdown]
# ## 5. Conclusão
#
# A Gold ficou com 29 tabelas, organizadas nas 7 pastas por pergunta do
# desafio, cada uma já no grão certo pra virar gráfico ou card na apresentação
# executiva direto, sem precisar processar nada de novo.
#
# AQUI PRECISAMOS DISCUTIR SE ESSA É A MELHOR ESTRATEGIA 29 TABELAS
